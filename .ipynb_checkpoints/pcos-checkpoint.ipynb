# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from warnings import filterwarnings
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
from sklearn.calibration import CalibratedClassifierCV

from sklearn.metrics import classification_report

# %% [markdown]
# **Veri Seti Ön İşleme**

# %%
df = pd.read_csv("PCOS_data/PCOS_data.csv")

# %%
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1  24.9           15                74                20  ...
# 2  25.3           11                72                18  ...
# 3  29.7           13                72                20  ...
# 4  20.1           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                  0                  110
# ...

# %%
df.drop('Unnamed: 44',axis=1,inplace=True)
df.drop('Sl. No',axis=1,inplace=True)
df.drop('Patient File No.',axis=1,inplace=True)
df = df.rename(columns = {"PCOS (Y/N)":"PCOS"})

# %%
df.head()
# Out:
#    PCOS   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 0     0          28         44.6        152.0  19.3           15
# 1     0          36         65.0        161.5  24.9           15
# 2     1          33         68.8        165.0  25.3           11
# 3     0          37         65.0        148.0  29.7           13
# 4     0          25         52.0        161.0  20.1           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# 0                78                22     10.48           2  ...
# 1                74                20     11.70           2  ...
# 2                72                18     11.80           2  ...
# 3                72                20     12.00           2  ...
# 4                72                18     10.00           2  ...
#
#    Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0             0              1.0                  0                  110
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PCOS                    541 non-null    int64
#  1    Age (yrs)              541 non-null    int64
#  2   Weight (Kg)             541 non-null    float64
#  3   Height(Cm)              541 non-null    float64
#  4   BMI                     541 non-null    float64
#  5   Blood Group             541 non-null    int64
#  6   Pulse rate(bpm)         541 non-null    int64
#  7   RR (breaths/min)        541 non-null    int64
#  8   Hb(g/dl)                541 non-null    float64
#  9   Cycle(R/I)              541 non-null    int64
#  10  Cycle length(days)      541 non-null    int64
#  11  Marraige Status (Yrs)   540 non-null    float64
#  12  Pregnant(Y/N)           541 non-null    int64
#  13  No. of abortions        541 non-null    int64
# ...

# %%
df['II    beta-HCG(mIU/mL)'] = pd.to_numeric(df['II    beta-HCG(mIU/mL)'],errors='coerce')
df['AMH(ng/mL)'] = pd.to_numeric(df['AMH(ng/mL)'],errors='coerce') #objectleri dönüştür

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PCOS                    541 non-null    int64
#  1    Age (yrs)              541 non-null    int64
#  2   Weight (Kg)             541 non-null    float64
#  3   Height(Cm)              541 non-null    float64
#  4   BMI                     541 non-null    float64
#  5   Blood Group             541 non-null    int64
#  6   Pulse rate(bpm)         541 non-null    int64
#  7   RR (breaths/min)        541 non-null    int64
#  8   Hb(g/dl)                541 non-null    float64
#  9   Cycle(R/I)              541 non-null    int64
#  10  Cycle length(days)      541 non-null    int64
#  11  Marraige Status (Yrs)   540 non-null    float64
#  12  Pregnant(Y/N)           541 non-null    int64
#  13  No. of abortions        541 non-null    int64
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}, xticklabels=True, yticklabels=True)
# Out:
# <Axes: >

# %%
lst_missing_columns = df.columns[df.isna().any()].tolist()
lst_missing_columns
# Out:
# ['Marraige Status (Yrs)',
#  'II    beta-HCG(mIU/mL)',
#  'AMH(ng/mL)',
#  'Fast food (Y/N)']

# %%
df_Kayip = df[['Marraige Status (Yrs)',
 'II    beta-HCG(mIU/mL)',
 'AMH(ng/mL)',
 'Fast food (Y/N)']]

# %%
df_Kayip.describe().T
# Out:
#                         count        mean          std   min   25%   50%  \
# Marraige Status (Yrs)   540.0    7.680926     4.803835  0.00  4.00  7.00
# II    beta-HCG(mIU/mL)  540.0  238.670480  1605.280485  0.99  1.99  1.99
# AMH(ng/mL)              540.0    5.624191     5.881608  0.10  2.01  3.70
# Fast food (Y/N)         540.0    0.514815     0.500244  0.00  0.00  1.00
#
#                            75%      max
# Marraige Status (Yrs)   10.000     30.0
# II    beta-HCG(mIU/mL)  98.145  25000.0
# AMH(ng/mL)               6.925     66.0
# Fast food (Y/N)          1.000      1.0

# %%
#Kayıp verileri ortanca değerle doldur
for x in lst_missing_columns:
    df[x] = df[x].fillna(df[x].median())

# %%
df.columns[df.isna().any()].tolist()
# Out:
# []

# %%
#korelasyon değerlerini inceleme
corr_pcos = df.corr()['PCOS'].abs().sort_values(ascending=False)
print(corr_pcos)
# Out:
# PCOS                      1.000000
# Follicle No. (R)          0.648327
# Follicle No. (L)          0.603346
# Skin darkening (Y/N)      0.475733
# hair growth(Y/N)          0.464667
# Weight gain(Y/N)          0.441047
# Cycle(R/I)                0.401644
# Fast food (Y/N)           0.376183
# Pimples(Y/N)              0.286077
# AMH(ng/mL)                0.264141
# Weight (Kg)               0.211938
# BMI                       0.199697
# Cycle length(days)        0.178480
# Hair loss(Y/N)            0.172879
#  Age (yrs)                0.168513
# Waist(inch)               0.164598
# Hip(inch)                 0.162297
# Avg. F size (L) (mm)      0.132992
# Marraige Status (Yrs)     0.113056
# Endometrium (mm)          0.106648
# Avg. F size (R) (mm)      0.097690
# Pulse rate(bpm)           0.091821
# Hb(g/dl)                  0.087170
# Vit D3 (ng/mL)            0.085494
# Height(Cm)                0.068254
# Reg.Exercise(Y/N)         0.065337
# LH(mIU/mL)                0.063879
# ...

# %%
#en etkili 10 değişken için yeni veri seti oluşturma
df_new = df[['PCOS',
               'Follicle No. (R)',
               'Follicle No. (L)',
               'Skin darkening (Y/N)',
               'hair growth(Y/N)',
               'Weight gain(Y/N)',
               'Cycle(R/I)',
               'Fast food (Y/N)',
               'Pimples(Y/N)',
               'AMH(ng/mL)',
               'Weight (Kg)']]

# %%
#yeni veri setinin korelasyon matrisi
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#yeni veri setinin korelasyon matrisi
plt.figure(figsize=(12,12))
sns.heatmap(df_new.corr(),annot=True)
plt.show()

# %%
df_new.describe().transpose()
# Out:
#                       count       mean        std   min    25%   50%   75%  \
# PCOS                  541.0   0.327172   0.469615   0.0   0.00   0.0   1.0
# Follicle No. (R)      541.0   6.641405   4.436889   0.0   3.00   6.0  10.0
# Follicle No. (L)      541.0   6.129390   4.229294   0.0   3.00   5.0   9.0
# Skin darkening (Y/N)  541.0   0.306839   0.461609   0.0   0.00   0.0   1.0
# hair growth(Y/N)      541.0   0.273567   0.446202   0.0   0.00   0.0   1.0
# Weight gain(Y/N)      541.0   0.377079   0.485104   0.0   0.00   0.0   1.0
# Cycle(R/I)            541.0   2.560074   0.901950   2.0   2.00   2.0   4.0
# Fast food (Y/N)       541.0   0.515712   0.500216   0.0   0.00   1.0   1.0
# Pimples(Y/N)          541.0   0.489834   0.500359   0.0   0.00   0.0   1.0
# AMH(ng/mL)            541.0   5.620634   5.876742   0.1   2.01   3.7   6.9
# Weight (Kg)           541.0  59.637153  11.028287  31.0  52.00  59.0  65.0
#
#                         max
# PCOS                    1.0
# ...

# %%
numerical_variables = []
categorical_variables = []
for x in df_new.columns:
    if len(df_new[x].value_counts()) < 9:
        if x not in ["Cycle(R/I)"]:
            categorical_variables.append(x)
    else:
        numerical_variables.append(x)

# %%
numerical_variables
# Out:
# ['Follicle No. (R)', 'Follicle No. (L)', 'AMH(ng/mL)', 'Weight (Kg)']

# %%
categorical_variables
# Out:
# ['PCOS',
#  'Skin darkening (Y/N)',
#  'hair growth(Y/N)',
#  'Weight gain(Y/N)',
#  'Fast food (Y/N)',
#  'Pimples(Y/N)']

# %%
for x in categorical_variables:
    if x != "PCOS":
        sns.barplot(x= x, y = "PCOS", data = df_new)
        plt.show()

# %%
features = ["Follicle No. (R)","Follicle No. (L)","AMH(ng/mL)","Weight (Kg)" ]
for i in features:
    sns.swarmplot(x=df_new["PCOS"], y=df_new[i], color="black", alpha=0.5 )
    sns.boxenplot(x=df_new["PCOS"], y=df_new[i])
    plt.show()

# %% [markdown]
# **Veri Setini Eğitme**

# %%
df_new.head()
# Out:
#    PCOS  Follicle No. (R)  Follicle No. (L)  Skin darkening (Y/N)  \
# 0     0                 3                 3                     0
# 1     0                 5                 3                     0
# 2     1                15                13                     0
# 3     0                 2                 2                     0
# 4     0                 4                 3                     0
#
#    hair growth(Y/N)  Weight gain(Y/N)  Cycle(R/I)  Fast food (Y/N)  \
# 0                 0                 0           2              1.0
# 1                 0                 0           2              0.0
# 2                 0                 0           2              1.0
# 3                 0                 0           2              0.0
# 4                 0                 0           2              0.0
#
#    Pimples(Y/N)  AMH(ng/mL)  Weight (Kg)
# 0             0        2.07         44.6
# 1             0        1.53         65.0
# ...

# %%
x_data = df_new.drop(['PCOS'],axis=1) 
y = df_new.PCOS.values

# %%
x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data)) #Normalizasyon

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# **Yöntem Uygulama**

# %%
score_list = []
for each in range(1,11):
    knn = KNeighborsClassifier(n_neighbors= each)
    knn.fit(x_train,y_train)
    score_list.append(knn.score(x_test,y_test))

plt.plot(range(1,11),score_list)
plt.xlabel("K Değeri")
plt.ylabel("2.Veri Seti İçin Doğruluk")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
knn = KNeighborsClassifier(9)
knn_model = knn.fit(x_train,y_train)
knn_model
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred = knn_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8834355828220859

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       113
#            1       0.90      0.70      0.79        50
#
#     accuracy                           0.88       163
#    macro avg       0.89      0.83      0.85       163
# weighted avg       0.88      0.88      0.88       163

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[109   4]
#  [ 15  35]]

# %%
y_scores=knn.predict_proba(x_test)
fpr,tpr,threshold =roc_curve(y_test,y_scores[:,1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr,'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of kNN')
plt.show()

# %%
rfd = RandomForestClassifier(n_estimators=100,random_state=1)
rf =rfd.fit(x_train,y_train)
rf
# Out:
# RandomForestClassifier(random_state=1)

# %%
y_pred = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9141104294478528

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       113
#            1       0.91      0.80      0.85        50
#
#     accuracy                           0.91       163
#    macro avg       0.91      0.88      0.90       163
# weighted avg       0.91      0.91      0.91       163

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[109   4]
#  [ 10  40]]

# %%
y_scores=rfd.predict_proba(x_test)
fpr,tpr,threshold =roc_curve(y_test,y_scores[:,1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr,'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of RF')
plt.show()

# %%
dtA = DecisionTreeClassifier()
dt = dtA.fit(x_train,y_train)
dt
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8773006134969326

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       113
#            1       0.83      0.76      0.79        50
#
#     accuracy                           0.88       163
#    macro avg       0.86      0.84      0.85       163
# weighted avg       0.88      0.88      0.88       163

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[105   8]
#  [ 12  38]]

# %%
y_scores=dtA.predict_proba(x_test)
fpr,tpr,threshold =roc_curve(y_test,y_scores[:,1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr,'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of CART')
plt.show()

# %%
model_svc = SVC(random_state=1)
svm = CalibratedClassifierCV(model_svc) 
svm.fit(x_train, y_train)
# Out:
# CalibratedClassifierCV(estimator=SVC(random_state=1))

# %%
y_pred = svm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8895705521472392

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       113
#            1       0.88      0.74      0.80        50
#
#     accuracy                           0.89       163
#    macro avg       0.89      0.85      0.86       163
# weighted avg       0.89      0.89      0.89       163

# %%
y_scores = svm.predict_proba(x_test)
fpr,tpr,threshold =roc_curve(y_test,y_scores[:,1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr,'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of SVM')
plt.show()

# %%
plt.figure(0).clf()

# %%
model = KNeighborsClassifier(9)
model.fit(x_train, y_train)
y_pred = model.predict_proba(x_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="K-Nearest Neighbor, AUC="+str(auc))

model = RandomForestClassifier(n_estimators=100,random_state=1)
model.fit(x_train, y_train)
y_pred = model.predict_proba(x_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Random Forest, AUC="+str(auc))

model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict_proba(x_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Decision Tree, AUC="+str(auc))

model = SVC(probability=True)
model.fit(x_train, y_train)
y_pred = model.predict_proba(x_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Support Vector Machine, AUC="+str(auc))

plt.plot([0, 1], [0, 1],'s--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of All')

plt.legend()
